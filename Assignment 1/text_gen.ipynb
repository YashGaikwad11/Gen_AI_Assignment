# %%
# !pip install -q google-genai

# %%
from google import genai

# %%
client = genai.Client(api_key="AIzaSyDakXbcanuSde9Gti9xW68CUBHSU_dwK_E")

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="How does AI work?"
)
print(response.text)
# Out:
# At its simplest level, Artificial Intelligence (AI) is a field of computer science that builds systems capable of performing tasks that usually require human intelligence. This includes things like recognizing faces, translating languages, making decisions, or writing stories.
#
# Unlike traditional software, which follows a strict list of "If-Then" rules written by a human, AI **learns from data.**
#
# Here is a breakdown of how it actually works:
#
# ---
#
# ### 1. The Foundation: Data
# AI needs "fuel" to work, and that fuel is **data**.
# *   To teach an AI to identify a cat, you don’t give it a definition of a cat. You show it millions of pictures of cats.
# *   To teach an AI to speak, you feed it almost every book, article, and website ever written.
#
# ### 2. The Engine: Machine Learning (ML)
# Machine Learning is the most common way we build AI today. Instead of a programmer writing instructions, they use an **algorithm** (a mathematical formula) that allows the computer to find patterns in the data on its own.
#
# There are three main ways it learns:
# *   **Supervised Learning:** The AI is given labeled data (e.g., "This is a photo of a cat; this is a photo of a dog"). It learns to associate specific features with those labels.
# *   **Unsupervised Learning:** The AI looks at unlabeled data and tries to find hidden structures or groups on its own (e.g., "I don't know what these are, but these 1,000 files look similar").
# *   **Reinforcement Learning:** The AI learns through trial and error, receiving "rewards" for good moves and "penalties" for bad ones (common in teaching AI to play video games or drive cars).
#
# ### 3. The Brain Structure: Neural Networks
# Modern AI (like ChatGPT or Midjourney) uses a technique called **Deep Learning**, which relies on **Artificial Neural Networks**. These are inspired by the human brain.
#
# *   **Layers:** A neural network consists of layers of "nodes" (mathematical functions).
# *   **Processing:** When information enters the network, it passes through these layers. Each layer looks for something different. In a face-recognition AI, the first layer might look for lines, the second for shapes (eyes/noses), and the final layer identifies the specific person.
# *   **Weights:** As the AI trains, it adjusts the "strength" (weights) of the connections between these nodes until it starts getting the right answers consistently.
#
# ### 4. How Generative AI (like ChatGPT) Works
# Generative AI doesn't actually "know" facts. It is essentially a **hyper-advanced version of autocomplete.**
#
# *   **Prediction:** When you ask ChatGPT a question, it isn't "thinking." It is calculating the statistical probability of which word (or part of a word, called a "token") should come next based on the trillions of sentences it has read.
# *   **Context:** It looks at the words you just typed and uses them as a guide to predict the most logical response.
#
# ### 5. The Three Main Ingredients
# To make modern AI work, you need three things:
# 1.  **Algorithms:** The mathematical models (the "logic").
# 2.  **Computing Power:** Powerful chips (GPUs) that can do billions of calculations per second.
# 3.  **Big Data:** The massive libraries of information used for training.
#
# ### Summary: Is it "Thinking"?
# No. While AI can seem human, it is essentially **complex mathematics and statistics.** It doesn’t have feelings, consciousness, or a "soul." It is a tool that identifies patterns in the past to predict or create things in the present.
